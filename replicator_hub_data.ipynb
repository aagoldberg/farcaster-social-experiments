# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
# LOG_LEVEL=info
# COLORIZE=true
# # Set this higher the further the hub is from the replicator
# CONCURRENCY=64
# WORKER_TYPE=thread
# WEB_UI_PORT=9000
# REDIS_URL=redis:6379
# POSTGRES_URL=postgres://replicator:password@postgres:5432/replicator
# STATSD_HOST=statsd:8125
# HUB_HOST=34.125.205.141:2283
# HUB_SSL=false

# %%
# "31b5067d4235a5ec4e848e9be545296080eb71c8996f1b4974aa1b6cb7bdcb9a": {
#                 "Name": "replicator-postgres-1",
#                 "EndpointID": "52d22099655da87b388fe0f768e4b725a21b66caac6c650b29ec9c541e0692b4",
#                 "MacAddress": "02:42:ac:13:00:05",
#                 "IPv4Address": "172.19.0.5/16",
#                 "IPv6Address": ""
#             },

# %%
db_url = "postgresql+psycopg2://replicator:password@35.238.13.184:9000/replicator?sslmode=require"
engine = create_engine(db_url)

# %%
likes_query = """
SELECT * FROM information_schema.tables;
"""
likes_df = pd.read_sql(likes_query, engine)
print(likes_df)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/base.py in __init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145             try:
# --> 146                 self._dbapi_connection = engine.raw_connection()
#     147             except dialect.loaded_dbapi.Error as err:
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/base.py in raw_connection(self)
#    3299         """
# -> 3300         return self.pool.connect()
#    3301
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/pool/base.py in connect(self)
#     448         """
# --> 449         return _ConnectionFairy._checkout(self)
#     450
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#    1262         if not fairy:
# ...

# %%
"31b5067d4235a5ec4e848e9be545296080eb71c8996f1b4974aa1b6cb7bdcb9a": {
                "Name": "replicator-postgres-1",
                "EndpointID": "52d22099655da87b388fe0f768e4b725a21b66caac6c650b29ec9c541e0692b4",
                "MacAddress": "02:42:ac:13:00:05",
                "IPv4Address": "172.19.0.5/16",
                "IPv6Address": ""
            },
