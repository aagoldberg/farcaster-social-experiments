# %%
# @title Setup
from google.colab import auth
# from google.cloud import bigquery
from google.colab import data_table
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from datetime import datetime, timedelta
import os

# %% [markdown]
# # Reactions

# %%
# pd.read_parquet('/content/drive/My Drive/farcaster_bigquery/verifications/verifications.parquet')

# %%
folder = '/content/drive/My Drive/farcaster_bigquery/reactions/parquet'
reactions_parquet = [ f.path for f in os.scandir(folder)]

# %%
initial_df = pd.read_parquet(reactions_parquet[0])
reactions_df = pd.DataFrame(columns = initial_df.columns)
reactions_df.head()
# Out:
# Empty DataFrame
# Columns: [fid, timestamp, target_cast_fid, target_cast_hash, type, deleted_at, date]
# Index: []

# %%
for filename in reactions_parquet:
  # if filename.split('.')[0][-8:-6] == '22':
    print(filename)
    df = pd.read_parquet(filename)
    reactions_df = pd.concat([reactions_df, df], ignore_index=True)
# Out:
# /content/drive/My Drive/farcaster_bigquery/reactions/parquet/reactions_2021-09-24.parquet
# /content/drive/My Drive/farcaster_bigquery/reactions/parquet/reactions_2021-09-27.parquet
# /content/drive/My Drive/farcaster_bigquery/reactions/parquet/reactions_2021-10-01.parquet
# /content/drive/My Drive/farcaster_bigquery/reactions/parquet/reactions_2021-10-03.parquet
# /content/drive/My Drive/farcaster_bigquery/reactions/parquet/reactions_2021-10-05.parquet
# /content/drive/My Drive/farcaster_bigquery/reactions/parquet/reactions_2021-10-22.parquet
# /content/drive/My Drive/farcaster_bigquery/reactions/parquet/reactions_2021-10-28.parquet
# /content/drive/My Drive/farcaster_bigquery/reactions/parquet/reactions_2021-11-04.parquet
# /content/drive/My Drive/farcaster_bigquery/reactions/parquet/reactions_2021-11-05.parquet
# /content/drive/My Drive/farcaster_bigquery/reactions/parquet/reactions_2021-11-08.parquet
# ...

# %%
reactions_df.to_parquet('/content/drive/My Drive/farcaster_bigquery/reactions.parquet')

# %%
reactions_df.head()
# Out:
#    fid                  timestamp  target_cast_fid  \
# 0  172  2021-09-24 18:52:41+00:00                3
# 1  172  2021-09-24 18:51:05+00:00              130
# 2  172  2021-09-24 18:51:21+00:00              130
# 3  172  2021-09-24 18:50:28+00:00                3
# 4  172  2021-09-24 18:50:39+00:00                3
#
#                              target_cast_hash  type deleted_at        date
# 0  0xdf881e166ee9550ec1528c6ab07b832d1d00d729  like        NaT  2021-09-24
# 1  0x1dc16369ede12cf3c513223c37715a9b425c9465  like        NaT  2021-09-24
# 2  0x2deae073eb7b552466d0c2693e928212208f7f21  like        NaT  2021-09-24
# 3  0x5fc0a7b09e2b9f007136f8e58501c01babb1e885  like        NaT  2021-09-24
# 4  0xffe60e155d9fb7875e1500513144bac938b960e3  like        NaT  2021-09-24

# %%
reactions_df.shape
# Out:
# (186440288, 7)

# %%
reactions_df.type.value_counts()
# Out:
# type
# like      154643837
# recast     31796451
# Name: count, dtype: int64
